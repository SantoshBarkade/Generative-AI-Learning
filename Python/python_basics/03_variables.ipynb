# %% [markdown]
# # Variables

# %% [markdown]
# ## Variables are the elements in the python that can be used for storing data into it or values into it or they can be referred as container as well .
# ##  variables as per their name, data can vary  that we are going to store into it and once we have declared a variable we can vary the value stored in it.

# %%
age=22
Name="santosh"
Height=5.9
is_true=True

# %%
Height
# Out:
# 5.9

# %%
Name
# Out:
# 'santosh'

# %% [markdown]
# # print()

# %% [markdown]
# ## print() --> print function is being used to represent the value we are going to pass inside it

# %%
print(age)
# Out:
# 22

# %%
print("Name is : " , Name)
# Out:
# Name is :  santosh

# %% [markdown]
# ## Comment
# ## Comment is statement in the program that we dont want the interpreter to execute
#
# ## Interpreter executes the code line by line in python language
#  ## Compiler  ---> executes the code completely

# %%
# Hello i am explaining about how to wite comments

# %%
'''name
santosh'''
# Out:
# 'name\nsantosh'

# %% [markdown]
# # Variable  Naming Convention

# %%
'''Variables names must be Descriptive : 
Age= 22
Name="Santosh"'''
# Out:
# 'Variables names must be Descriptive : \nAge= 22\nName="Santosh"'

# %%
''' they must start with a letter or underscore and can contain letters , numbers and underscores but cannot start with a number.'''

# %%
_name="Santosh"

# %%
''' variables are also case sensitive '''

# %%
name="Santosh"
Name="Santosh"
name==Name
# Out:
# True

# %%
Age=22
Name="Chetan"
is_true=True
print(type(Age))
print(type(Name))
print(type(is_true))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %%
Age=45

# %%
print(Age)
# Out:
# 45

# %%
Age=str(Age)
print(Age)
print(type(Age))
# Out:
# 45
# <class 'str'>

# %%
Name="santosh"
Name=int(Name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 Name="santosh"
# ----> 2 Name=int(Name)
#
# ValueError: invalid literal for int() with base 10: 'santosh'

# %%
'''
Every type casting is not possible 
int --> str is possible
str---> int is not possible'''
# Out:
# '\nEvery type casting is not possible \nint --> str is possible\nstr---> int is not possible'

# %% [markdown]
# # input() Function
#
# ## input () can take input from user side and then can store that  input into a variable

# %%
Name=input("Enter your name: ")

# %%
print(Name)
# Out:
# Santosh

# %% [markdown]
# ## input () only takes input in string format until and unless we are not going to explicitely take the input in integer  or  other format

# %%
Age = input("Enter your age: ")
print(type(Age))
# Out:
# <class 'str'>

# %%
Age= int(input("Enter your age: "))
print(type(Age))
# Out:
# <class 'int'>

# %%
Age= float(input("Enter your age: "))
print(type(Age))
# Out:
# <class 'float'>

# %%
Value=bool(input("Enter the value:"))
print(type(Value))
# Out:
# <class 'bool'>

# %%
Value
# Out:
# True

# %%
## building a simple 

value_1= int(input("Enter the first value:"))
value_2= int(input("Enter the second value:"))
print("Addition for the value is :", value_1 + value_2)
print("substraction for the value is :", value_1 - value_2)
print("multiplication for the value is :", value_1 * value_2)
# Out:
# Addition for the value is : 25
# substraction for the value is : 15
# multiplication for the value is : 100
