# %% [markdown]
# # Data Types

# %% [markdown]
# ## Data Types  are classification of the data that tells the compiler or interpreter that what kind of values  we can store into a variable and  how much amount of memory will be consumed to store the  data and the operation it can perform

# %%
age=input("Enter the Age")

# %%
age
# Out:
# '22'

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age2='Hello'

# %%
print(age+age2)
# Out:
# 22Hello

# %%
a= str()

# %%
type(a)
# Out:
# str

# %% [markdown]
# # Different types of Data Types

# %% [markdown]
# ##
#  1. int
# 2. str
# 3. bool
# 4. float

# %%
a=23
type(a)
# Out:
# int

# %%
b="santosh"
type(b)
# Out:
# str

# %%
is_true=True
type(is_true)
# Out:
# bool

# %%
a=7
b=7

a==b
# Out:
# True

# %%
a=23
b=29
a==b
# Out:
# False
