# %% [markdown]
# # Keywords

# %% [markdown]
# ## keywords are the reserved words which cant be used as our variable name as they are having a reserved meaning already in python

# %%
list = "Santosh Barkade"
print(list)
# Out:
# Santosh Barkade

# %%
list
# Out:
# 'Santosh Barkade'

# %%
set
# Out:
# set

# %% [markdown]
# tuple
