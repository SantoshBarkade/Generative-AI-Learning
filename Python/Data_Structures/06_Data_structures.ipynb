# %% [markdown]
# # Data Structures in Python

# %% [markdown]
# ## Data strucutres in python are being used for storing the data in structured format so  that we can access the data and along with that we can perform all of the operations with these data structures that we can perform  in the case of databases as well like CRUD (create, read, update, delete)

# %% [markdown]
# ## Types of data structures :
#  1. List
#  2. Tuple
#  3. Set
#  4. Dictionary

# %% [markdown]
# ## Different types of data strucctures differes on this basis that in which specific format we want to store our data
